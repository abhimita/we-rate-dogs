# %% [markdown]
# # <center>Introduction</center>
#
# This reports outlines data analysis done for tweets of `WeRateDogs`. My analysis focuses around comparison of metric values (e.g. likes and retweets) based on gender of dogs. Also I investigated any existing correlation between dog rating, likes and retweets.
# Finally I have analyzed whether dog ratings show any temporal behavior for the given dataset.

# %% [markdown]
# ## <center>Visualization</center>

# %% [markdown]
# I start by comparing likes by gender to see if this data tells me any story whether male or female dogs got higher likes. The breakup of `likes` (sum of likes) by gender is as follows. It exhibits that number of male dogs in this dataset is large than number of female dogs. So instead of comparing sum of likes, I should focus on comparing median value.
#
#
# | Gender | Likes | Dog Count|
# | --- | --- | --- |
# | Female | 2947736 | 275 |
# | Male | 8763542 | 930 |
# | Unknown | 3393506 | 459 |

# %% [markdown]
# Following is the median `like` values by gender.
#
# | Gender | Likes |	Dog count |
# | -- | -- | -- |
# | Female | 5227 | 275 |
# | Male | 4653.5 | 930 |
# | Unknown | 3233.0 | 459 |

# %% [markdown]
# Equivalent bar graph visualization is attached here.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The bar graph indicates that "like" count is higher for female dogs rather than male dogs. Gender of dog is a derived field based on the use of pronoun in tweet text.

# %% [markdown]
# Continuing the same analysis, I add another metric - `retweet count`. This is a metric indicating how many times the tweet has been retweeted and is a metric that can be used as a measure of popularity of the image.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Here again I observe that number of retweets for female dogs is higher than male dogs
# Out:
#   File "<ipython-input-1-e85634f894f5>", line 1
#     Here again I observe that number of retweets for female dogs is higher than male dogs
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# `ratings` is another metric value of interest. Does the female dogs in the dataset show higher median rating?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The median value of rating for female dog slightly higher than male dog.

# %% [markdown]
# `retweet_count` indicates number of retweets of the given tweet
# `favorite_count` indicates number of likes of the tweet
#
# I wanted to explore if data shows any corelation between these metrics as well as `ratings` of dog. I used `seaborn` pairplot for visualization. Followed by that I used Pandas to compute correlation using Pearson method. `retweet_count` and `faviorite_count` has strong correlation with `r = 0.93`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# `favorite_count` & `retweet_count` shows a strong correlation. For these two metric values `r = 0.931`

# %% [markdown]
# Median value of dog rating is 1.1. Dog rating is a continuous quantitative variable. I plan to analyze to see if this data set shows any relationship between rating & likes.
#
# To perform that analysis, I bucketize `rating` column. The new column is named `rating_bucket`.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Plot of median value of `likes` & `retweets` shows an upward trend of likes & retweet for dogs having more than median rating (1.1)

# %% [markdown]
# Next step is to explore if median value of `likes` and `tweets` show any temporal trend
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Number of retweet and likes increased over time. This is most probably because of twitter handle `ewratedog` became popular overtime.

# %% [markdown]
# ## <center>Insights</center>

# %% [markdown]
# * Images which get rating <= 1.0, are getting low number of likes and retweets. Images from 1.0 and above get high number of likes and retweets
# * Scatter plot shows strong correlation between `likes` and `retweets` with r = 0.93 So higher likes is expected to have higher retweets ans vice versa
# * Retweets and likes show increase in volume over time. Most probably it is because of popularity to `weratedogs` over time.
# * Female dogs outperform male dogs in median value of like & retweet.
# * Female dogs get higher median rating (1.2) compared to (1.1) for male dogs.
